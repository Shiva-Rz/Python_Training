# %%
import pandas as pd
import numpy as np

# %%
# file_1 = pd.read_csv('employees.csv', delimiter = ',', index_col = range(1,21))

file_1 = pd.read_csv('employees.csv', delimiter = ',', skiprows = range(20, 1000))
file_1.index += 1

# %%
file_1
# Out:
#    First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 1     Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2      Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 3       Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 4       Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 5       Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 6      Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 7        Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 8         NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 9      Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 10    Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 11     Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 12      Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 13    Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(file_1['Salary'], file_1['Last Login Time'])
plt.show()
